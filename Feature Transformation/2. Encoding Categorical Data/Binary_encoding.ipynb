# %%
import pandas as pd 
from category_encoders import BinaryEncoder
import numpy as np 
from sklearn.model_selection import train_test_split

# %%
pip install category_encoders
# Out:
# ...
#
# ...

# %%
data=pd.read_csv(r'C:\Users\Lenovo\Downloads\ordinal_label_data.csv')
data
# Out:
#     Age Income_Level Education_Level  Customer_Satisfaction Preferred_Brand  \
# 0    22          Low     High School                      4               A
# 1    34       Medium        Bachelor                      3               B
# 2    26       Medium        Bachelor                      3               B
# 3    45         High          Master                      5               C
# 4    36         High          Master                      5               C
# ..  ...          ...             ...                    ...             ...
# 75   24          Low     High School                      2               A
# 76   32       Medium        Bachelor                      3               B
# 77   21          Low     High School                      2               A
# 78   39         High          Master                      5               C
# 79   49         High       Doctorate                      5               C
#
#    Churn_Label
# 0           No
# 1          Yes
# ...

# %%
data=data.iloc[:,2:]
data = data.rename(columns={'Customer_Satisfaction': 'customer'})
df = data.drop(columns='customer')
df
# Out:
#    Education_Level Preferred_Brand Churn_Label
# 0      High School               A          No
# 1         Bachelor               B         Yes
# 2         Bachelor               B          No
# 3           Master               C          No
# 4           Master               C         Yes
# ..             ...             ...         ...
# 75     High School               A          No
# 76        Bachelor               B         Yes
# 77     High School               A          No
# 78          Master               C          No
# 79       Doctorate               C         Yes
#
# [80 rows x 3 columns]

# %%
X_train,X_test,y_train,y_test=train_test_split(df[['Education_Level','Preferred_Brand']],df['Churn_Label'],test_size=0.2)
X_train
# Out:
#    Education_Level Preferred_Brand
# 63          Master               C
# 74       Doctorate               C
# 44          Master               C
# 11     High School               A
# 53       Doctorate               C
# ..             ...             ...
# 10        Bachelor               B
# 25       Doctorate               C
# 71     High School               A
# 73       Doctorate               C
# 58          Master               C
#
# [64 rows x 2 columns]

# %%
encoder=BinaryEncoder(cols='Education_Level')

# %%
df_train=encoder.fit_transform(X_train)

# %%
df_train
# Out:
#     Education_Level_0  Education_Level_1  Education_Level_2 Preferred_Brand
# 63                  0                  0                  1               C
# 74                  0                  1                  0               C
# 44                  0                  0                  1               C
# 11                  0                  1                  1               A
# 53                  0                  1                  0               C
# ..                ...                ...                ...             ...
# 10                  1                  0                  0               B
# 25                  0                  1                  0               C
# 71                  0                  1                  1               A
# 73                  0                  1                  0               C
# 58                  0                  0                  1               C
#
# [64 rows x 4 columns]
